# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/Housing.csv")

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
data['mainroad']=data['mainroad'].apply({'yes':1,'no':0}.get)

# %%
data['basement']=data['basement'].apply({'yes':1,'no':0}.get)

# %%
data['prefarea']=data['prefarea'].apply({'yes':1,'no':0}.get)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad guestroom  basement  \
# 0  13300000  7420         4          2        3         1        no         0
# 1  12250000  8960         4          4        4         1        no         0
# 2  12250000  9960         3          2        2         1        no         1
# 3  12215000  7500         4          2        2         1        no         1
# 4  11410000  7420         4          1        2         1       yes         1
#
#   hotwaterheating airconditioning  parking  prefarea furnishingstatus
# 0              no             yes        2         1        furnished
# 1              no             yes        3         0        furnished
# 2              no              no        2         1   semi-furnished
# 3              no             yes        3         1        furnished
# 4              no             yes        2         0        furnished

# %%
data['guestroom']=data['guestroom'].apply({'yes':2,'no':3}.get)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          3
# 1  12250000  8960         4          4        4         1          3
# 2  12250000  9960         3          2        2         1          3
# 3  12215000  7500         4          2        2         1          3
# 4  11410000  7420         4          1        2         1          2
#
#    basement hotwaterheating airconditioning  parking  prefarea  \
# 0         0              no             yes        2         1
# 1         0              no             yes        3         0
# 2         1              no              no        2         1
# 3         1              no             yes        3         1
# 4         1              no             yes        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
data['airconditioning']=data['airconditioning'].apply({'yes':1,'no':0}.get)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          3
# 1  12250000  8960         4          4        4         1          3
# 2  12250000  9960         3          2        2         1          3
# 3  12215000  7500         4          2        2         1          3
# 4  11410000  7420         4          1        2         1          2
#
#    basement hotwaterheating  airconditioning  parking  prefarea  \
# 0         0              no                1        2         1
# 1         0              no                1        3         0
# 2         1              no                0        2         1
# 3         1              no                1        3         1
# 4         1              no                1        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
data['furnishingstatus']=data['furnishingstatus'].apply({'furnished':1,'semi-furnished':0,'unfurnished':2}.get)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          3
# 1  12250000  8960         4          4        4         1          3
# 2  12250000  9960         3          2        2         1          3
# 3  12215000  7500         4          2        2         1          3
# 4  11410000  7420         4          1        2         1          2
#
#    basement hotwaterheating  airconditioning  parking  prefarea  \
# 0         0              no                1        2         1
# 1         0              no                1        3         0
# 2         1              no                0        2         1
# 3         1              no                1        3         1
# 4         1              no                1        2         0
#
#    furnishingstatus
# 0                 1
# 1                 1
# 2                 0
# 3                 1
# 4                 1

# %%
data['hotwaterheating']=data['hotwaterheating'].apply({'yes':1,'no':0}.get)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          3
# 1  12250000  8960         4          4        4         1          3
# 2  12250000  9960         3          2        2         1          3
# 3  12215000  7500         4          2        2         1          3
# 4  11410000  7420         4          1        2         1          2
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 1
# 1                 1
# 2                 0
# 3                 1
# 4                 1

# %%
x=data[['area','bedrooms','bathrooms','stories','mainroad','guestroom','basement','hotwaterheating','airconditioning','parking','prefarea','furnishingstatus']]
y=data['price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(x_test)

# %%
regression.score(x,y)
# Out:
# 0.67614082095289

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          3
# 1  12250000  8960         4          4        4         1          3
# 2  12250000  9960         3          2        2         1          3
# 3  12215000  7500         4          2        2         1          3
# 4  11410000  7420         4          1        2         1          2
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 1
# 1                 1
# 2                 0
# 3                 1
# 4                 1

# %%
new_data={'area':10000,'bedrooms':4,'bathrooms':3,'stories':4,'mainroad':1,'guestroom':3,'basement':1,'hotwaterheating':0,'airconditioning':1,'parking':2,'prefarea':1,'furnishingstatus':1}

# %%
index=[1]

# %%
my_data=pd.DataFrame(new_data,index)

# %%
my_data
# Out:
#     area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 1  10000         4          3        4         1          3         1
#
#    hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 1                0                1        2         1                 1

# %%
new_pred=regression.predict(my_data)

# %%
print(new_pred)
# Out:
# [10565952.46902011]
